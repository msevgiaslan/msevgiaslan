# %% [markdown]
# <a href="https://colab.research.google.com/github/msevgiaslan/msevgiaslan/blob/main/covid19world.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("novel_corona_virus_dataset[1].csv")

# %%
df
# Out:
#        State               Country        Lat        Long     Date  Confirmed  \
# 0        NaN           Afghanistan  33.939110   67.709953  1/22/20          0
# 1        NaN               Albania  41.153300   20.168300  1/22/20          0
# 2        NaN               Algeria  28.033900    1.659600  1/22/20          0
# 3        NaN               Andorra  42.506300    1.521800  1/22/20          0
# 4        NaN                Angola -11.202700   17.873900  1/22/20          0
# ...      ...                   ...        ...         ...      ...        ...
# 280614   NaN    West Bank and Gaza  31.952200   35.233200  9/18/22     702768
# 280615   NaN  Winter Olympics 2022  39.904200  116.407400  9/18/22        535
# 280616   NaN                 Yemen  15.552727   48.516388  9/18/22      11932
# 280617   NaN                Zambia -13.133897   27.849332  9/18/22     333382
# 280618   NaN              Zimbabwe -19.015438   29.154857  9/18/22     256996
#
# ...

# %%
df.shape
# Out:
# (280619, 9)

# %%
df.count()
# Out:
# State         88361
# Country      280619
# Lat          278677
# Long         278677
# Date         280619
# Confirmed    280619
# Deaths       280619
# Recovered    280619
# Active       280619
# dtype: int64

# %%
df.isnull().sum()
# Out:
# State        192258
# Country           0
# Lat            1942
# Long           1942
# Date              0
# Confirmed         0
# Deaths            0
# Recovered         0
# Active            0
# dtype: int64

# %%
df = df.drop('State', axis=1)

# %%
df.isnull().sum()
# Out:
# Country         0
# Lat          1942
# Long         1942
# Date            0
# Confirmed       0
# Deaths          0
# Recovered       0
# Active          0
# dtype: int64

# %%
df.fillna(0, inplace=True)

# %%
df.isnull().sum()
# Out:
# Country      0
# Lat          0
# Long         0
# Date         0
# Confirmed    0
# Deaths       0
# Recovered    0
# Active       0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(df.isnull())
plt.show()

# %%
df.head()
# Out:
#        Country       Lat       Long     Date  Confirmed  Deaths  Recovered  \
# 0  Afghanistan  33.93911  67.709953  1/22/20          0       0          0
# 1      Albania  41.15330  20.168300  1/22/20          0       0          0
# 2      Algeria  28.03390   1.659600  1/22/20          0       0          0
# 3      Andorra  42.50630   1.521800  1/22/20          0       0          0
# 4       Angola -11.20270  17.873900  1/22/20          0       0          0
#
#    Active
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df.groupby("Country").sum()
# Out:
#                                Lat           Long  \
# Country
# Afghanistan           32954.875810   65746.364363
# Albania               39959.854300   19583.419300
# Algeria               27220.916900    1611.471600
# Andorra               41273.617300    1477.667800
# Angola               -10877.821700   17355.556900
# ...                            ...            ...
# West Bank and Gaza    31025.586200   34211.437200
# Winter Olympics 2022  38746.978200  113031.585400
# Yemen                 15101.697917   47109.412748
# Zambia               -12753.013987   27041.701372
# Zimbabwe             -18463.990298   28309.366147
#
#                                                                    Date  \
# Country
# Afghanistan           1/22/201/23/201/24/201/25/201/26/201/27/201/28...
# Albania               1/22/201/23/201/24/201/25/201/26/201/27/201/28...
# Algeria               1/22/201/23/201/24/201/25/201/26/201/27/201/28...
# ...

# %%
df.groupby("Country").sum().head(25)
# Out:
#                                   Lat          Long  \
# Country
# Afghanistan              32954.875810  6.574636e+04
# Albania                  39959.854300  1.958342e+04
# Algeria                  27220.916900  1.611472e+03
# Andorra                  41273.617300  1.477668e+03
# Angola                  -10877.821700  1.735556e+04
# Antarctica              -69863.352900  2.266994e+04
# Antigua and Barbuda      16566.036800 -6.000430e+04
# Argentina               -37302.033100 -6.177182e+04
# Armenia                  38907.096100  4.373209e+04
# Australia              -249401.544200  1.098049e+06
# Austria                  46138.230200  1.412815e+04
# Azerbaijan               38978.950100  4.619717e+04
# Bahamas                  24300.134335 -7.577285e+04
# Bahrain                  25272.702500  4.908405e+04
# Bangladesh               22998.135000  8.773597e+04
# Barbados                 12811.276900 -5.781645e+04
# Belarus                  52152.215800  2.714275e+04
# ...

# %%
df.groupby("Country")["Confirmed"].sum()
# Out:
# Country
# Afghanistan              94632209
# Albania                 128206168
# Algeria                 136112462
# Andorra                  16427568
# Angola                   42082209
#                           ...
# West Bank and Gaza      291613458
# Winter Olympics 2022       122442
# Yemen                     5825236
# Zambia                  138114186
# Zimbabwe                 95701057
# Name: Confirmed, Length: 201, dtype: int64

# %%
df.groupby("Country")["Confirmed"].sum().sort_values(ascending=False)
# Out:
# Country
# US                36652659767
# India             21449280871
# Brazil            15027003427
# France             9521949582
# United Kingdom     7940751108
#                      ...
# Holy See                21819
# MS Zaandam               8117
# Antarctica               3069
# Tuvalu                   1046
# Korea, North              128
# Name: Confirmed, Length: 201, dtype: int64

# %%
df.groupby("Country")["Confirmed"].sum().sort_values(ascending=False)
# Out:
# Country
# US                36652659767
# India             21449280871
# Brazil            15027003427
# France             9521949582
# United Kingdom     7940751108
#                      ...
# Holy See                21819
# MS Zaandam               8117
# Antarctica               3069
# Tuvalu                   1046
# Korea, North              128
# Name: Confirmed, Length: 201, dtype: int64

# %%
df.groupby("Country")["Confirmed"].sum().sort_values(ascending=True)
# Out:
# Country
# Korea, North              128
# Tuvalu                   1046
# Antarctica               3069
# MS Zaandam               8117
# Holy See                21819
#                      ...
# United Kingdom     7940751108
# France             9521949582
# Brazil            15027003427
# India             21449280871
# US                36652659767
# Name: Confirmed, Length: 201, dtype: int64

# %%
df[df.Country=="US"]
# Out:
#        Country   Lat   Long     Date  Confirmed   Deaths  Recovered    Active
# 260         US  40.0 -100.0  1/22/20          1        0          0         1
# 549         US  40.0 -100.0  1/23/20          1        0          0         1
# 838         US  40.0 -100.0  1/24/20          2        0          0         2
# 1127        US  40.0 -100.0  1/25/20          2        0          0         2
# 1416        US  40.0 -100.0  1/26/20          5        0          0         5
# ...        ...   ...    ...      ...        ...      ...        ...       ...
# 279434      US  40.0 -100.0  9/14/22   95456800  1052313          0  94404487
# 279723      US  40.0 -100.0  9/15/22   95586479  1052939          0  94533540
# 280012      US  40.0 -100.0  9/16/22   95645794  1053389          0  94592405
# 280301      US  40.0 -100.0  9/17/22   95653526  1053412          0  94600114
# 280590      US  40.0 -100.0  9/18/22   95658236  1053419          0  94604817
#
# [971 rows x 8 columns]

# %%
df.groupby("Country")[	"Recovered" ].sum()
# Out:
# Country
# Afghanistan             18289880
# Albania                 22652652
# Algeria                 25670233
# Andorra                  3085649
# Angola                   5895800
#                           ...
# West Bank and Gaza      57608773
# Winter Olympics 2022           0
# Yemen                     772497
# Zambia                  21852796
# Zimbabwe                 8779035
# Name: Recovered, Length: 201, dtype: int64

# %%
df[df.Country=="Pakistan"]
# Out:
#          Country      Lat     Long     Date  Confirmed  Deaths  Recovered  \
# 210     Pakistan  30.3753  69.3451  1/22/20          0       0          0
# 499     Pakistan  30.3753  69.3451  1/23/20          0       0          0
# 788     Pakistan  30.3753  69.3451  1/24/20          0       0          0
# 1077    Pakistan  30.3753  69.3451  1/25/20          0       0          0
# 1366    Pakistan  30.3753  69.3451  1/26/20          0       0          0
# ...          ...      ...      ...      ...        ...     ...        ...
# 279384  Pakistan  30.3753  69.3451  9/14/22    1571530   30604          0
# 279673  Pakistan  30.3753  69.3451  9/15/22    1571530   30604          0
# 279962  Pakistan  30.3753  69.3451  9/16/22    1571732   30605          0
# 280251  Pakistan  30.3753  69.3451  9/17/22    1571732   30605          0
# 280540  Pakistan  30.3753  69.3451  9/18/22    1571894   30607          0
#
#          Active
# 210           0
# 499           0
# 788           0
# ...

# %%
df.groupby("Country")["Long"].sum()
# Out:
# Country
# Afghanistan              65746.364363
# Albania                  19583.419300
# Algeria                   1611.471600
# Andorra                   1477.667800
# Angola                   17355.556900
#                             ...
# West Bank and Gaza       34211.437200
# Winter Olympics 2022    113031.585400
# Yemen                    47109.412748
# Zambia                   27041.701372
# Zimbabwe                 28309.366147
# Name: Long, Length: 201, dtype: float64

# %%
df.Confirmed<10
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 280614    False
# 280615    False
# 280616    False
# 280617    False
# 280618    False
# Name: Confirmed, Length: 280619, dtype: bool
